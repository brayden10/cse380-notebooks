# %% [markdown]
# <a href="https://colab.research.google.com/github/brayden10/cse380-notebooks/blob/master/ponder_and_prove_conditional_probability_and_Bayes_theorem.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Ponder and Prove Conditional Probability and Bayes' Theorem**
# Due: Saturday, 13 February 2021, 11:59pm

# %% [markdown]
# # TODO Watch a Video on Bayes' Theorem

# %% [markdown]
# [and making probability intuitive](https://www.youtube.com/watch?v=HZGCoVF3YvM), 15.75 minutes long.

# %% [markdown]
# # TODO Apply Bayes’ Theorem

# %% [markdown]
# Automating the process of finding bugs in source code requires the use of heuristics, or pattern-matching on the code. There is no deep understanding of the code involved, hence such a tool cannot be perfect at detecting bugs. A certain bug-detection tool is correct 80% of the time and incorrect the rest of the time. This means that on average out of every 100 bugs, the tool will detect 80 of them, and fail to detect 20 of them. Also, out of 100 non-bugs, the tool will report 20 bugs and 80 non-bugs, on average. The tool is run on source code that is 10% buggy. That is, one line out of every ten contains a bug. Given that the tool detects a bug in some line of code, what is the probability that this line of code actually contains a bug?

# %% [markdown]
# Know:<br>
# The program will find 8 buggy lines in 10 buggy lines. <br>
# The program will misidentify 2 lines in 10 as buggy. <br>
# The current program has 1 buggy line per 10 lines.<br>

# %% [markdown]
# ![bayes theorem.png](data:image/png;base64,...)

# %% [markdown]
# The answer is
# $ P(H|E) = \frac{8}{8 + 18} = 8/26 = 4/13 $

# %% [markdown]
# There is about a 30.7% chance (or 4/13) that the line identified as a buggy line does in fact have a bug in it.

# %% [markdown]
# $$\begin{array}{|r|r|r|r|}
#   \hline
#   & & & \\
#   & P(\overline{H}) & P(H) & Margin \\
#   \hline
#   & & & \\
#   P(T) & P(\overline{H} \cap T) & P(H \cap T) &  \\
#   & & & \\
#   & = P(\overline{H}\vert{}T) \cdot P(T) & = P(H\vert{}T) \cdot P(T) & \\
#   & = P(T\vert{}\overline{H}) \cdot P(\overline{H}) & = P(T\vert{}H) \cdot P(H) & \\
#   & & & \\
#   \hline
#   & & & \\
#   P(\overline{T}) & P(\overline{H} \cap \overline{T}) & P(H \cap \overline{T}) & \\
#   & & & \\
#   & = P(\overline{H}\vert{}\overline{T}) \cdot P(\overline{T}) & = P(H\vert{}\overline{T}) \cdot P(\overline{T}) & \\
#   & = P(\overline{T}\vert{}\overline{H}) \cdot P(\overline{H}) & = P(\overline{T}\vert{}H) \cdot P(H) & \\
#   & & & \\
#   \hline
#   & & & \\
#   & & & \\
#   \hline
#   \end{array}$$

# %% [markdown]
# Givens:
#
# $$ P(H) = 0.1 \\
# P(T|H) = 0.8\\
# P(!T|!H) = 0.8\\
#
# $$

# %% [markdown]
# Calculations:
#
#
# $P(H \cap T) = (0.1)(0.8) = 0.08 $
#
# $P(H \cap !T) = (0.1)(0.08) = 0.008 $
#
# $P(T|!H) = 1 - (0.8) = 0.2 $
#
# $P(!H \cap T) = (0.2)(0.9) = 0.18$
#
# $P(!H \cap !T) = (0.2)(0.8) = 0.16$
#
# $ P(!T) = P(!H \cap !T) + P(H \cap !T) = (0.16) + (0.008) = 0.168 $
#
# $ P(T) = 1 - P(!T) = 1 - 0.168 = 0.832

# %% [markdown]
# ** False positive rate: **

# %% [markdown]
# # TODO Compute Four Leaves

# %% [markdown]
# Using the information in the previous task, calculate to two-decimal-digit precision, the values that go at the leaves of the binary tree shown below:
#
# ![fig-binary-tree-with-four-leaves.png](data:image/png;base64,...)

# %% [markdown]
# The value that goes at leaf number 1 is calculated by $P(H) \cdot P(T|H)$. The other three values are calculated similarly.
#
# Hint: The four leaves correspond to the four quadrants of trutH versus tesT described in this brief introduction to [Bayes' Theorem](https://byui-cse.github.io/cse380-course/Bayes-Theorem.pdf). (Compare this to the video you watched.)
#
# ### Put your answers here:
# 1. $P(H) \cdot P(T|H)$ = (.1)(.8) = 0.08 (Probability that it is a bug and is reported)
# 2. $P(H) \cdot P(!T|H)$ = (.1)(.2) = 0.02 (Probability that it is a bug but not reported)
# 3. $P(!H) \cdot P(T|!H)$ = (.9)(.2) = 0.18 (Probability that it is not a bug but is reported)
# 4. $P(!H) \cdot P(!T|!H)$ = (.9)(.8) = 0.72 (Probability that it is not a bug and is not reported.)

# %% [markdown]
# # TODO Apply Your Probability Knowledge

# %% [markdown]
# There are three sheets of paper in a folder. One sheet has writing on both sides, one has writing on one side and is blank on the other side, and the third sheet of paper is blank on both sides. Without looking you randomly pull one sheet of paper out of the folder and see that it is blank on the side you're looking at. What is the probability that the other side is blank as well?

# %% [markdown]
# You have a 2/3 chance of having the other side of the page be blank. This is due to the fact that there are 3 blank sides total and 1 with writing on it. You have found 1 blank side, which leaves 2 blank pages and 1 non-blank page.

# %% [markdown]
# # TODO Apply Bayes Theorem Generalized

# %% [markdown]
# Three different vegetables, turnips, eggplant and asparagus, make Bill sick sometimes. There is a 50% chance he will be sick if he eats turnips. If he eats eggplant, there is a 20% chance he will be sick. The probability that he will be sick when he eats asparagus is only 5%.
#
# Bill gets sick after dinner where he ate one of those three vegetables. What is the probability that he ate turnips?
#
# (Assume that for each of the three vegetables, there is a 1/3 chance he ate it.)

# %% [markdown]
# Know: <br>
# 50% turnips <br>
# 20% eggplant <br>
# 5% asparagus <br>
# He ate one of the 3 and got sick. <br>

# %% [markdown]
# $ \frac{\frac{1}{2}}{\frac{1}{2} + \frac{1}{5} + \frac{1}{20}} = \frac{2}{3}$ Thus he has a 2/3 chance of having eaten turnips.

# %% [markdown]
# # TODO Apply Bayes Theorem Generalized With Different **Priors**

# %% [markdown]
# Change the prior probabilities of Bill eating these vegetables to a 30% chance he ate turnips, a 10% chance he ate eggplant, and a 60% chance he ate asparagus.
#
# Now what is the probability that Bill ate turnips, given that he got sick?

# %% [markdown]
# $ \frac{(0.5)(0.3)}{(0.5)(0.3)+(0.2)(0.1)+(0.05)(0.6)} = 0.75$ That is a 75% chance.

# %% [markdown]
# # TODO My Report on What I Did and What I Learned

# %% [markdown]
# ## Fun
# I had a lot of fun. I watched the video and enjoyed learning about probability and the bayes theorem I also had fun doing things with my group mates.

# %% [markdown]
# ## New
# I learned about the bayes therom and how it workes to provide a probability.

# %% [markdown]
# ## Meaningful
# If I was to name somthing meeningfull that was acomplished for this assignment I would say that one part that I think my group mates and i will use is part two finding the four leaves. I suggested that not only should we write what the mathmatical equasion was but also what they meen. this should help when we have questions about it in the future.

# %% [markdown]
# ## Response
# I actualy really enjoyed the video. I learned how a probability space is seperated into four parts the bayes theorm only uses two of them, to put it in simple turms it uses the double positive and the false positive and becomes the double positive devided by the false positive plus the double positive. A screenshot was added today of the video we watched in order to help us understand what we needed to do I hope that is ok.

# %% [markdown]
# ## Other
# I worked with three other students thay are Matthew Read, Davis Kerr and Paul Semadeni we try to get together every wednesday and work on something usualy the PAP. I will be honest when I say I am happy to be in a group with such smart people. I always learn a lot. What I mostly do is make sure everone stayes on track and that we all work together and understand what we are doing. I try to make it so that we are not just coppying what the other group mates are saying but that we all contribute somthing. This means i am often the one to ask questions.

# %% [markdown]
# # TODO What is True?
# Click on each warranted checkbox to toggle it to True (or back to False).
#
# NOTE: *This only works in Colab. If you run it in some other Jupyter notebook client/server environment you may have to change False to True (or vice versa) manually.*
#
# This self-assessment is subject to revision by a grader.

# %%
#@markdown ## What is true about what I did?
#@markdown ### I had fun.
cb00 = True #@param {type:'boolean'}
#@markdown ### I learned something new.
cb01 = True #@param {type:'boolean'}
#@markdown ### I achieved something meaningful, or something I can build upon at a later time.
cb02 = True #@param {type:'boolean'}
#@markdown ### I watched the linked-to 3Blue1Brown video on Bayes' Theorem, and reported on the experience.
cb03 = True #@param {type:'boolean'}
#@markdown ## What is true about my report?
#@markdown ### I wrote a sufficient number of well-written sentences.
cb04 = True #@param {type:'boolean'}
#@markdown ### My report is free of mechanical infelicities.
cb05 = True #@param {type:'boolean'}
#@markdown ### I used Grammarly (or something better described in my report) to check for MIs.
cb06 = True #@param {type:'boolean'}
#@markdown ### I reported on any connections I found between these problems and something I already know. 
cb07 = True #@param {type:'boolean'}
#@markdown ### I reported who were and what contribution each of my collaborators made.
cb08 = True #@param {type:'boolean'}
#@markdown ## What is true about my answers?
#@markdown ### I got the right answer for the "Apply Bayes' Theorem" problem, and my report describes how I know it.
cb09 = True #@param {type:'boolean'}
#@markdown ### I got the right answer for the "Compute Four Leaves" problem, and my report describes how I know it.
cb10 = True #@param {type:'boolean'}
#@markdown ### I got the right answer for the "Apply Your Probability Knowledge" problem, and my report describes how I know it.
cb11 = True #@param {type:'boolean'}
#@markdown ### I got the right answer for the "Apply Bayes' Theorem Generalized" problem, and my report describes how I know it.
cb12 = True #@param {type:'boolean'}
#@markdown ### I got the right answer for the "Apply Bayes' Theorem Generalized With Different Priors" problem, and my report describes how I know it.
cb13 = True #@param {type:'boolean'}

# %% [markdown]
# ## DO NOT CHANGE ANYTHING IN THE NEXT CODE CELL!!

# %%
points_for_what_I_did = [2.5]*4
points_for_my_report = [8]*5
points_for_my_answers = [10]*5
points = points_for_what_I_did + points_for_my_report + points_for_my_answers
# cb is short for checkbox
total = sum(map(lambda n, p: p if eval(f'cb{n:02}') else 0,
                range(len(points)), points))             
total

# %% [markdown]
# # For graders

# %%
#@markdown ---
number_of_MIs_found = 0 #@param {type: 'slider', min: 0, max: 5}
#@markdown ---
